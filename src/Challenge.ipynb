# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/electric_vehicles.csv", sep=";", index_col=0)
df['City'] = df['City'].str.replace('\d+ ', '')
# Out:
# C:\Users\jchop\AppData\Local\Temp/ipykernel_48440/1959812668.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['City'] = df['City'].str.replace('\d+ ', '')

# %%
growth_rate_2021=(df["2021"]-df["2020"])/df["2020"]
growth_rate_2020=(df["2020"]-df["2019"])/df["2019"]
growth_rate_2019=(df["2019"]-df["2018"])/df["2018"]
growth_rate_2018=(df["2018"]-df["2017"])/df["2017"]
growth_rate_mean=(growth_rate_2021+growth_rate_2020+growth_rate_2019+growth_rate_2018)/4
df["2022_pred"] = round(df["2021"]*(1+growth_rate_mean))
df["2023_pred"] = round(df["2021"]*((1+growth_rate_mean)**2))
df["2024_pred"] = round(df["2021"]*((1+growth_rate_mean)**3))
df
# Out:
#                      City  2017  2018  2019  2020  2021  2022_pred  2023_pred  \
# Index
# 1         Aeugst am Albis     7     8    13    27    39       61.0       96.0
# 2      Affoltern am Albis    29    35    54    75   103      142.0      196.0
# 3              Bonstetten    18    21    29    37    70      100.0      143.0
# 4         Hausen am Albis    16    21    25    32    45       58.0       76.0
# 5                Hedingen    14    22    31    45    56       79.0      113.0
# ...                   ...   ...   ...   ...   ...   ...        ...        ...
# 6806         Vendlincourt     0     0     0     0     3        NaN        NaN
# 6807        Basse-Allaine     2     2     3     5     9       13.0       20.0
# 6808        Clos du Doubs     0     0     2     6     9        NaN        NaN
# 6809          Haute-Ajoie     0     0     1     1     2        NaN        NaN
# 6810           La Baroche     3     2     3     5     6        8.0       10.0
#
#        2024_pred
# Index
# 1          152.0
# 2          270.0
# 3          204.0
# 4           98.0
# 5          160.0
# ...          ...
# 6806         NaN
# 6807        30.0
# 6808         NaN
# 6809         NaN
# 6810        12.0
#
# [2163 rows x 9 columns]

# %%
dv_ev_final = pd.read_excel("../data/excel.xlsx")
dv_ev_final
# Out:
#                    City  Count
# 0     Gondiswil Schweiz    1.0
# 1                Sattel    1.0
# 2               Steinen    3.0
# 3                Aadorf    2.0
# 4                 Aarau   16.0
# ...                 ...    ...
# 1113               Zuoz    2.0
# 1114             Zuzwil    3.0
# 1115           Zweidlen    1.0
# 1116         Zweisimmen    6.0
# 1117             Zürich   39.0
#
# [1118 rows x 2 columns]

# %%
df = pd.merge(df, dv_ev_final, on="City")
df
# Out:
#                    City  2017  2018  2019  2020  2021  2022_pred  2023_pred  \
# 0    Affoltern am Albis    29    35    54    75   103      142.0      196.0
# 1            Bonstetten    18    21    29    37    70      100.0      143.0
# 2        Mettmenstetten    20    26    36    41    60       79.0      105.0
# 3              Obfelden    11    18    30    40    68      108.0      171.0
# 4               Adlikon     1     5     4     6    11       25.0       57.0
# ..                  ...   ...   ...   ...   ...   ...        ...        ...
# 686          Montfaucon     1     1     1     3     4        6.0       10.0
# 687         Le Noirmont     0     1     1     3    12        inf        inf
# 688        Saignelégier     1     2     3     9    14       28.0       57.0
# 689          Porrentruy     7    10    15    29    49       80.0      131.0
# 690        Vendlincourt     0     0     0     0     3        NaN        NaN
#
#      2024_pred  Count
# 0        270.0    5.0
# 1        204.0    2.0
# 2        139.0    3.0
# 3        270.0    1.0
# 4        131.0    1.0
# ..         ...    ...
# 686       16.0    1.0
# 687        inf    3.0
# 688      114.0    1.0
# 689      215.0    3.0
# 690        NaN    1.0
#
# [691 rows x 10 columns]

# %%
df["recomm_2022"] = round(df["Count"]*(1+(df["2022_pred"]-df["2021"])/df["2021"]))
df["recomm_2023"] = round(df["recomm_2022"]*(1+(df["2023_pred"]-df["2022_pred"])/df["2022_pred"]))
df["recom_2024"] = round(df["recomm_2023"]*(1+(df["2024_pred"]-df["2023_pred"])/df["2023_pred"]))
df
# Out:
#                    City  2017  2018  2019  2020  2021  2022_pred  2023_pred  \
# 0    Affoltern am Albis    29    35    54    75   103      142.0      196.0
# 1            Bonstetten    18    21    29    37    70      100.0      143.0
# 2        Mettmenstetten    20    26    36    41    60       79.0      105.0
# 3              Obfelden    11    18    30    40    68      108.0      171.0
# 4               Adlikon     1     5     4     6    11       25.0       57.0
# ..                  ...   ...   ...   ...   ...   ...        ...        ...
# 686          Montfaucon     1     1     1     3     4        6.0       10.0
# 687         Le Noirmont     0     1     1     3    12        inf        inf
# 688        Saignelégier     1     2     3     9    14       28.0       57.0
# 689          Porrentruy     7    10    15    29    49       80.0      131.0
# 690        Vendlincourt     0     0     0     0     3        NaN        NaN
#
#      2024_pred  Count  recomm_2022  recomm_2023  recom_2024
# 0        270.0    5.0          7.0         10.0        14.0
# 1        204.0    2.0          3.0          4.0         6.0
# 2        139.0    3.0          4.0          5.0         7.0
# 3        270.0    1.0          2.0          3.0         5.0
# 4        131.0    1.0          2.0          5.0        11.0
# ..         ...    ...          ...          ...         ...
# 686       16.0    1.0          2.0          3.0         5.0
# 687        inf    3.0          inf          NaN         NaN
# 688      114.0    1.0          2.0          4.0         8.0
# 689      215.0    3.0          5.0          8.0        13.0
# 690        NaN    1.0          NaN          NaN         NaN
#
# [691 rows x 13 columns]

# %%
df.to_csv("ev_communes.csv")
